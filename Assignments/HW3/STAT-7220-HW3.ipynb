# %% [markdown]
# # STAT 7220 - Homework 3
# ## Factorial Designs
# ## Dr. Austin Brown
# ## Due Date: November 21, 2025
#
# ## Part 1 Instructions:
#
# A running shoe manufacturer wants to optimize the comfort of a new shoe model. They've identified three factors they believe will affect comfort:
#
# | Factor | Level 1 (-) Description | Level 2 (+) Description |
# |------------------------|------------------------|-------------------------|
# | Sole Material (A) | Standard EVA foam | Advanced gel-infused foam |
# | Insole Thickness (B) | 3mm | 6mm |
# | Fabric Breathability (C) | Standard woven fabric | High-performance mesh fabric |
#
# To evaluate the comfort of the $2^3=8$ runs, the manufacturer will recruit 3 NCAA division one cross-country athletes to test a randomly assigned shoe. Each athlete will run on a treadmill for 30 minutes in the shoes and rate the comfort on a scale of 1-10 (1 = very uncomfortable, 10 = very comfortable). The results of this experiment are contained in the `Shoe Comfort Experiment.xlsx` file. With these data, I want you to:

# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "garrettspringsted"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
    print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
    print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #

today_dir = "Factorial Designs"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/garrettspringsted/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/garrettspringsted/STAT-7220-Applied-Experimental-Design.git
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Factorial Designs

# %% [markdown]
# 1.  Briefly describe the objective of the experiment.
#
#  **The objective of this experiment is to determine how sole material, insole thickness, and fabric breathability affect the comfort rating of a running shoe. This includes evaluating both the main effects and interactions of these factors, as well as identifying the combination of factor levels that produces the highest comfort.**

# %% [markdown]
# 2.  Specify the outcome variable and how it is measured.
#
# **The outcome variable is the comfort rating of the running shoe, measeured on a scale from 1-10 where 1 is very uncomfortable and 10 is very comfortable**

# %% [markdown]
# 3.  Specify the independent variables. What lurking variables may be present?
#
# **The independent variabel(IV) for this experiment are the sole material, insole thickness, and fabric breathability.**
# **Some of the possible lurking variables may include the stride of the runner, the foot shape of the runners, the age and condition of the treadmill on which they are running. The speed that they are running. The weight of the runner. The freshness of the runner(i.e.time of day)(fatigue). The personal preference of the runner(opinion).**

# %% [markdown]
# 4.  Explain the difference between a full factorial design and a $2^k$ factorial design. Briefly comment on why the latter may be preferred in this case.
#
# **A full factorial design includes all possible combinations of the factir levels. A 2^k factorial design is a specific type of full factorial design in which there are k factors, each at 2 levels, resulting in 2^k total experiments run.**
#
# **The 2^k factorial design may be preferred for this experiment because it allows efficiency in studying multiple factors and their interaction using a smaller number of runs. This makes it practical and cost effective.**

# %% [markdown]
# 5.  State the sets of null and alternative hypotheses for this experiment.
#
# • Our hypotheses in this case would be the same as our hypotheses for a three-factor factorial design.
#
# • For our main effects:
#
# $$ H_{01}: \alpha_{\text{Standard EVA}} = \alpha_{\text{Gel}} = 0 $$
# $$ H_{11}: \text{At least one } \alpha_i \neq 0 $$
#
# $$ H_{02}: \beta_{\text{3mm}} = \beta_{\text{6mm}} = 0 $$
# $$ H_{12}: \text{At least one } \beta_j \neq 0 $$
#
# $$ H_{03}: \gamma_{\text{Standard Fabric}} = \gamma_{\text{Mesh}} = 0 $$
# $$ H_{13}: \text{At least one } \gamma_k \neq 0 $$
#
# • For our two-way interactions:
#
# $$ H_{04}: (\alpha\beta)_{ij} = 0 \text{ for all } i,j $$
# $$ H_{14}: \text{At least one } (\alpha\beta)_{ij} \neq 0 $$
#
# $$ H_{05}: (\alpha\gamma)_{ik} = 0 \text{ for all } i,k $$
# $$ H_{15}: \text{At least one } (\alpha\gamma)_{ik} \neq 0 $$
#
# $$ H_{06}: (\beta\gamma)_{jk} = 0 \text{ for all } j,k $$
# $$ H_{16}: \text{At least one } (\beta\gamma)_{jk} \neq 0 $$
#
# • For our three-way interaction:
#
# $$ H_{07}: (\alpha\beta\gamma)_{ijk} = 0 \text{ for all } i,j,k $$
# $$ H_{17}: \text{At least one } (\alpha\beta\gamma)_{ijk} \neq 0 $$

# %% [markdown]
# 6.  Perform appropriate exploratory analysis, including data visualizations. Do the results of these analyses support the null or alternative hypotheses more strongly?
#
# **Exploratory analysis was conducted by calculating the mean and standard deviation of comfort ratings for sole material, insole thickness, and breathability, along with interaction summary statistics. Boxplots and interaction plots were also used to visually assess patterns in the data.**
#
# **The summary statistics and visualizations suggest that comfort ratings differ across factor levels, which provides evidence of possible main effects. The interaction plot also suggests that the effect of sole material may depend on the level of insole thickness, since the mean profiles are not identical across groups.**
#
# **Overall, these exploratory results support the alternative hypotheses more strongly than the null hypotheses, since differences in comfort ratings are observed across the levels and combinations of the factors.**

# %%
## Import pandas library ##
import pandas as pd
import numpy as np

## Import Shoe Comfort Experiment.xlsx File ##
shoe = pd.read_excel("../Assignments/HW3/Shoe Comfort Experiment.xlsx")

## Data Integrity Check ##
print(shoe.info())

## Calculate Means & SDs of Sole Material ##
sole_stats = shoe.groupby("sole_material")["comfort"].agg(['mean','std'])
print(sole_stats)

## Means and Standard Deviations for Insole Thickness ##
insole_stats = shoe.groupby("insole_thickness")["comfort"].agg(['mean','std'])
print(insole_stats)

## Means and Standard Deviations for Breathability ##
breath_stats = shoe.groupby("breathability")["comfort"].agg(['mean','std'])
print(breath_stats)

## Interaction Effect Summary Stats ##
int_stats = shoe.groupby(['sole_material','insole_thickness'])['comfort'].agg(['mean','std'])
print(int_stats)

## Import seaborn and matplotlib ##
import seaborn as sns
import matplotlib.pyplot as plt

#################################
## Create the boxplot using seaborn ##
sns.set_style("whitegrid")

sns.boxplot(
    data=shoe,
    x='sole_material',
    y='comfort',
    hue='insole_thickness'
)

## Calculate Means Per Sole Material ##
mean_points = shoe.groupby('sole_material')['comfort'].mean().reset_index()

## Overlay Mean Points ##
sns.scatterplot(data=mean_points,x="sole_material",y="comfort",
                marker='X',s=100,color='black',label='Mean',
                zorder=3)

## Add labels and titles ##
plt.title('Boxplot of Comfort by Sole Material with Insole Thickness Fill and Mean Overlay')
plt.ylabel('Comfort Rating')
plt.xlabel('Sole Material')
plt.legend()
plt.tight_layout()
plt.show()

###############################################
## First, let's grab the interaction means ##
int_means = shoe.groupby(['sole_material','insole_thickness'])['comfort'].mean().reset_index()

## Next, Create Interaction Plot with Seaborn ##
sns.set_style('whitegrid')

sns.lineplot(data=int_means,
             x='sole_material',
             y='comfort',
             hue='insole_thickness',
             marker='o',
             markersize=10,
             style='insole_thickness')

## Add Titles and Labels ##
plt.title('Mean Comfort by Sole Material and Insole Thickness')
plt.ylabel('Comfort Rating')
plt.xlabel('Sole Material')
plt.show()

#########################
## Step 1: Create a figure and a single axes object to plot on. ##
fig, ax = plt.subplots(figsize=(12, 8))

## Step 2: Plot the boxplot first, on the raw data. ##
sns.boxplot(data=shoe, x='sole_material', y='comfort', hue='insole_thickness',
            palette='viridis', dodge=True, ax=ax, zorder=2)

## Step 3: Overlay the interaction plot (line plot of the means). ##
sns.lineplot(data=shoe, x='sole_material', y='comfort', hue='insole_thickness',
             marker='o', markersize=10, ax=ax, zorder=3,
             estimator='mean', err_style=None, linestyle='--',
             palette='dark')

## Step 4: Clean up the plot: set titles, labels, and theme. ##
ax.set_title('Interaction Plot of Mean Comfort Overlaid on Boxplot', fontsize=16)
ax.set_xlabel('Sole Material', fontsize=12)
ax.set_ylabel('Comfort Rating', fontsize=12)

## Adjust legend to avoid duplicate labels ##
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[:2], labels[:2], title='Insole Thickness')

## Apply a classic theme by removing the top and right spines. ##
sns.despine()
plt.tight_layout()

## Show Plot ##
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sole_material     24 non-null     object
#  1   insole_thickness  24 non-null     object
#  2   breathability     24 non-null     object
#  3   comfort           24 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 900.0+ bytes
# None
#                mean       std
# sole_material
# EVA            7.10  1.068559
# Gel            9.05  1.541841
#                   mean       std
# insole_thickness
# 3mm               7.45  1.375434
# 6mm               8.70  1.687925
#                    mean       std
# breathability
# Mesh           7.508333  1.273120
# Woven          8.641667  1.808796
#                                     mean       std
# sole_material insole_thickness
# EVA           3mm               6.483333  0.840040
# ...

# %% [markdown]
# 7. Fit a full factorial ANOVA model to the data. Assess the normality assumption using both a visual method and a testing method. Do we have evidence to support the assumption of normality? Why or why not?
#
# **A full factorial ANOVA model was fit to the data, including the main effects of sole material, insole thickness, and breathability, as well as all interaction terms.**
#
# **The normality assumption was assessed using both a Q-Q plot and the Shapiro-Wilk test. The Q-Q plot showed that the residuals were approximately along the reference line, suggesting that the residuals are reasonably normal.**
#
# **The Shapiro-Wilk test produced a p-value of 0.390. Since this p-value is greater than 0.05, we fail to reject the null hypothesis that the residuals are normally distributed.Therefore, there is no evidence against the normality assumption, and the assumption appears to be satisfied..**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats



mod = ols('comfort ~ sole_material*insole_thickness*breathability', data=shoe).fit()

print(mod.summary())

## Test Normality Assumption ##

residuals = mod.resid

## Generate QQ plot using seaborn ##

sm.qqplot(residuals, line='s')
plt.title("QQ Plot of Model Residuals")
plt.style.use('classic')
plt.show()

## S-W Test ##

sw = stats.shapiro(residuals)
sw_statistic = sw[0]
sw_p_value = sw[1]

print(f"S-W Statistic: {sw_statistic}")
print(f"S-W p-value: {sw_p_value}")

if sw_p_value < 0.05:
    print("Reject the null hypothesis: Residuals are not normally distributed.")
else:
    print("Fail to reject the null hypothesis: Residuals are normally distributed.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                comfort   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     6.826
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           0.000742
# Time:                        23:16:59   Log-Likelihood:                -28.756
# No. Observations:                  24   AIC:                             73.51
# Df Residuals:                      16   BIC:                             82.94
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 8.  Assess the constant variance assumption using both a visual method and a testing method. Do we have evidence to support the assumption of constant variance? Why or why not?
#
# **The constant variance assumption was assessed using a residuals versus fitted values plot and the Breusch-Pagan test.The residual plot shows that the points are randomly scattered around zero with no clear pattern or funnel shape, suggesting that the variance is approximately constant.The Breusch-Pagan test resulted in a p-value of 0.0818. Since this p-value is greater than 0.05, we fail to reject the null hypothesis of constant variance. Therefore, there is no evidence to suggest that the variance is not constant, and the assumption of constant variance appears to be satisfied.**

# %%
    ## Constant Variance ##

## Obtain Standardized Residuals ##
standardized_residuals = mod.get_influence().resid_studentized_internal

## Get the fitted values ##
fitted_values = mod.fittedvalues

## Create the plot ##
plt.figure(figsize=(8, 6))
sns.scatterplot(x=fitted_values, y=standardized_residuals)
plt.axhline(y=0, linestyle='dashed', color='red')
plt.axhline(y=3, color='blue')
plt.axhline(y=-3, color='blue')
plt.xlabel("Predicted y's")
plt.ylabel("Standardized Residuals")
plt.title("Standardized Residuals vs. Fitted Values")
plt.style.use('classic')
plt.show()

from statsmodels.stats.diagnostic import het_breuschpagan
bp_test = het_breuschpagan(mod.resid, mod.model.exog)

f_statistic = bp_test[2]
f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")
# Out:
# F-statistic: 2.278431684215503
# F p-value: 0.0818079385294926

# %% [markdown]
# 9.  Report the F-statistics and their associated p-values from the factorial ANOVA model. What conclusions can we draw about our main effects? Our two-way interactions? Our three-way interaction?
#
# **The F-statistics and associated p-values from the factorial ANOVA model were examined for each main effect and interaction.**
#
# **For the main effects, sole material had an F-statistic of 5.813 with a p-value of 0.028, indicating that it is statistically significant. In contrast, insole thickness (F = 0.691, p = 0.418) and breathability (F = 0.085, p = 0.775) were not statistically significant. This suggests that sole material has a significant effect on comfort ratings, while insole thickness and breathability do not.**
#
# **For the two-way interactions, none were statistically significant. Specifically, the interaction between sole material and insole thickness (F = 0.312, p = 0.584), sole material and breathability (F ≈ 0, p = 1.000), and insole thickness and breathability (F = 0.999, p = 0.332) were all not significant. This indicates that there is no evidence that the effect of one factor depends on the level of another factor.**
#
# **For the three-way interaction, the interaction between sole material, insole thickness, and breathability (F = 0.691, p = 0.418) was also not statistically significant. This suggests that there is no combined interaction effect among the three factors.**
#
# **Overall, the results indicate that sole material is the only significant factor affecting comfort, and there is no evidence of interaction effects.**

# %%
shoe_tab = sm.stats.anova_lm(mod, typ=3)

shoe_tab["Significance"] = np.where(shoe_tab['PR(>F)'] < 0.05,
                                    'Significant',
                                    'Not Significant')

print(shoe_tab.loc[['sole_material',
                    'insole_thickness',
                    'breathability',
                    'sole_material:insole_thickness',
                    'sole_material:breathability',
                    'insole_thickness:breathability',
                    'sole_material:insole_thickness:breathability']])
# Out:
#                                                     sum_sq   df             F  \
# sole_material                                 5.606667e+00  1.0  5.812527e+00
# insole_thickness                              6.666667e-01  1.0  6.911447e-01
# breathability                                 8.166667e-02  1.0  8.466523e-02
# sole_material:insole_thickness                3.008333e-01  1.0  3.118790e-01
# sole_material:breathability                   9.466331e-30  1.0  9.813907e-30
# insole_thickness:breathability                9.633333e-01  1.0  9.987041e-01
# sole_material:insole_thickness:breathability  6.666667e-01  1.0  6.911447e-01
#
#                                                 PR(>F)     Significance
# sole_material                                 0.028297      Significant
# insole_thickness                              0.418010  Not Significant
# breathability                                 0.774810  Not Significant
# ...

# %% [markdown]
# 10. Calculate and interpret the partial $\eta^2$ values for each of the main effects and interactions. Which effects and/or interactions are most important? Why?
#
# **Partial η² values were calculated to assess the relative importance of each main effect and interaction in explaining variability in comfort ratings.**
#
# **The results show that sole material has the largest partial η² value (η² = 0.266), indicating that it explains the greatest proportion of variability in comfort ratings. In comparison, insole thickness (η² = 0.041) and breathability (η² = 0.005) have much smaller values, suggesting they contribute less to the variation in comfort.**
#
# **Among the interaction effects, all partial η² values are relatively small. The largest interaction effect is between insole thickness and breathability (η² = 0.059), but it is still much smaller than the effect of sole material. The remaining interaction effects are minimal and do not meaningfully contribute to explaining variability in the response.**
#
# **Overall, sole material is the most important factor, as it accounts for the largest share of variability in comfort ratings, while the other factors and interactions have relatively minor effects.**

# %%
## Calculate Partial Eta Squared ##

# Extract residual sum of squares
ss_res = shoe_tab.loc['Residual', 'sum_sq']

# Compute partial eta squared for each effect
eta_sq = shoe_tab['sum_sq'] / (shoe_tab['sum_sq'] + ss_res)

# Add to table
shoe_tab['Partial_Eta_Sq'] = eta_sq

# Print relevant rows
print(shoe_tab.loc[['sole_material',
                    'insole_thickness',
                    'breathability',
                    'sole_material:insole_thickness',
                    'sole_material:breathability',
                    'insole_thickness:breathability',
                    'sole_material:insole_thickness:breathability']])
# Out:
#                                                     sum_sq   df             F  \
# sole_material                                 5.606667e+00  1.0  5.812527e+00
# insole_thickness                              6.666667e-01  1.0  6.911447e-01
# breathability                                 8.166667e-02  1.0  8.466523e-02
# sole_material:insole_thickness                3.008333e-01  1.0  3.118790e-01
# sole_material:breathability                   9.466331e-30  1.0  9.813907e-30
# insole_thickness:breathability                9.633333e-01  1.0  9.987041e-01
# sole_material:insole_thickness:breathability  6.666667e-01  1.0  6.911447e-01
#
#                                                 PR(>F)  Partial_Eta_Sq
# sole_material                                 0.028297    2.664766e-01
# insole_thickness                              0.418010    4.140787e-02
# breathability                                 0.774810    5.263723e-03
# ...

# %% [markdown]
# 11. Summarize your conclusions. Which combination of factors would you recommend to the shoe manufacturer? Why?
#
# **Based on the results of the factorial ANOVA, sole material was the only statistically significant factor affecting comfort ratings, while insole thickness, breathability, and all interaction effects were not significant.**
#
# **Additionally, the partial η² results showed that sole material accounted for the largest proportion of variability in comfort, further confirming that it is the most important factor in this experiment.**
#
# **Therefore, the shoe manufacturer should prioritize using the gel-infused sole material, as it leads to higher comfort ratings. Since insole thickness and breathability were not statistically significant, either level of these factors may be used without substantially affecting comfort.**
#
# **Overall, the recommended combination is to use the advanced gel-infused sole, while insole thickness and fabric breathability can be selected based on other considerations such as cost or durability, as they do not significantly impact comfort.**

# %% [markdown]
# ## PART 2 INSTRUCTIONS:
# The same company is interested in developing a new GPS-enabled fitness band for runners. They want to maximize user satisfaction and have identified three key factors:
#
# | Run | GPS Accuracy (A) | Battery Life (B) | Display (C) |
# |-----|------------------|------------------|-------------|
# | 1   | \- (Standard)    | \- (6 hours)     | \- (Small)  |
# | 2   | \+ (High)        | \- (6 hours)     | \+ (Large)  |
# | 3   | \- (Standard)    | \+ (12 hours)    | \+ (Large)  |
# | 4   | \+ (High)        | \+ (12 hours)    | \- (Small)  |
#
# Due to time and resource limitations, the company would rather conduct a $2^{3-1}$ fractional factorial experiment. For each of the above runs, the company will recruit 3 NCAA division one cross-country athletes to test a randomly assigned fitness band. Each athlete will use the band for one month during their competition season. At the end of the month, the athletes will be asked to rate their level of satisfaction on a scale of 1-10 (1 = very dissatisfied, 10 = very satisfied). The results of this experiment are contained in the `Fitness Band Experiment.xlsx` file. With these data, I want you to:
#
# 1.  Briefly describe the objective of the experiment.
#
# **The objective of this experiment is to determine how GPS accuracy, battery life, and display size affect user satisfaction with the fitness band. The goal is to identify which factors have the greatest effect on satisfaction and to figure out which factor level(s) produce the highest satisfaction rating.**

# %% [markdown]
# 2.  Specify the outcome variable and how it is measured.
#
# **The outcome varible in this experiment is the Level of satisfaction rating on a scale from 1-10, with 1 being very dissatisfied and 10 being very satisfied.**

# %% [markdown]
# 3.  Specify the independent variables. What lurking variables may be present?
#
# **The Independent Variables in this experiment are the three crieteria being measured including GPS accuracy, Battery Life, and Display. Possible lurking variables could be the arm on which the user wears the band, duration of run, connectivity of device(urban v. rural), user eyesight, temperature, individual charging, familiarity with fitness devices/bands/etc.**

# %% [markdown]
# 4.  Explain the difference between a full $2^k$ factorial design and a $2^{3-1}$ fractional factorial design. Briefly comment on why the latter may be preferred in this case.
#
# **A full 2^k factorial design includes all possible combinations of the factor levels. A 2^3-1 fractional factorial design uses only a subset of these runs, specifically half of the full design.**
#
# **The advantage of the fractional factorial design is that it requires fewer experimental runs, making it more efficient in terms of time and resources. However, this comes at the cost of confounding, where some effects are aliased with others.**
#
# **In this case, the 2^3-1 design is preferred because it allows the company to study the effects of the factors while reducing the number of runs required to collect data. This saves the company time and money.**

# %% [markdown]
# 5.  State the sets of null and alternative hypotheses for this experiment.
#
# • For our main effects:
#
# $$ H_{01}: \alpha_{\text{Standard}} = \alpha_{\text{High}} = 0 $$
# $$ H_{11}: \text{At least one } \alpha_i \neq 0 $$
#
# $$ H_{02}: \beta_{\text{6hr}} = \beta_{\text{12hr}} = 0 $$
# $$ H_{12}: \text{At least one } \beta_j \neq 0 $$
#
# $$ H_{03}: \gamma_{\text{Small}} = \gamma_{\text{Large}} = 0 $$
# $$ H_{13}: \text{At least one } \gamma_k \neq 0 $$
#
# • For our two-way interactions:
#
# $$ H_{04}: (\alpha\beta)_{ij} = 0 \text{ for all } i, j $$
# $$ H_{14}: \text{At least one } (\alpha\beta)_{ij} \neq 0 $$
#
# $$ H_{05}: (\alpha\gamma)_{ik} = 0 \text{ for all } i, k $$
# $$ H_{15}: \text{At least one } (\alpha\gamma)_{ik} \neq 0 $$
#
# $$ H_{06}: (\beta\gamma)_{jk} = 0 \text{ for all } j, k $$
# $$ H_{16}: \text{At least one } (\beta\gamma)_{jk} \neq 0 $$
#
# • For our three-way interaction:
#
# $$ H_{07}: (\alpha\beta\gamma)_{ijk} = 0 \text{ for all } i, j, k $$
# $$ H_{17}: \text{At least one } (\alpha\beta\gamma)_{ijk} \neq 0 $$

# %% [markdown]
# 6.  Assuming a defining relation of $I=ABC$, specify the aliasing structure of the design. What does this mean for the interpretation of the main effects and interactions?
#
#  **The alias structure can be determined by using the defining relation, I = ABC, Multiplying any column by the defining relation will yield the alias of that column.**
#
# **Aliasing structure is:**
#
# **A = BC**
# **B = AC**
# **C = AB**
#
# **AB = C**
# **AC = B**
# **BC = A**
#
# **ABC = I**
#
# **Each main effect is aliased with a two-way interaction, and each two-way interaction is aliased with a main effect.The main effects are confounded with the two-factor interactions.Any significant effect may be due to either the main effect or the aliased interaction.**

# %% [markdown]
# 7.  Perform appropriate exploratory analysis, including data visualizations. Do the results of these analyses support the null or alternative hypotheses more strongly?
#
# **Exploratory analysis was conducted for GPS accuracy, battery life, and display size. Mean and standard deviation values were calculated for each factor, along with interaction summaries and boxplots.**
#
# **For GPS accuracy, the mean satisfaction rating for the high level was 7.14 compared to 4.61 for the standard level, suggesting increase in satisfaction when GPS accuracy is high.**
#
# **For battery life, the mean satisfaction rating was 6.37 for 12 hours and 5.38 for 6 hours, suggesting a moderate increase in satisfaction with longer battery life.**
#
# **For display size, the mean satisfaction rating was 7.51 for the large display and 4.24 for the small display, indicating a strong effect of display size on satisfaction. Bigger may be better.**
#
# **The interaction summary shows that the highest satisfaction rating (9.27) occurs when GPS accuracy is high and battery life is 12 hours, while the lowest (3.47) occurs when GPS accuracy is standard and battery life is 12 hours. This suggests a possible interaction between GPS accuracy and battery life.**
#
# **However, because this is a fractional factorial design, the effects are aliased. This means that observed differences may be due to either the main effects or their corresponding interactions. with that being said, the exploratory results provide stronger support for the alternative hypotheses,with caution.**

# %%
import pandas as pd
import numpy as np

band = pd.read_excel("../Assignments/HW3/Fitness Band Experiment.xlsx")

print(band.info())

gps_stats = band.groupby("GPS_Accuracy")["Satisfaction"].agg(['mean','std'])
print(gps_stats)

battery_stats = band.groupby("Battery_Life")["Satisfaction"].agg(['mean','std'])
print(battery_stats)

display_stats = band.groupby("Display")["Satisfaction"].agg(['mean','std'])
print(display_stats)

int_stats = band.groupby(['GPS_Accuracy','Battery_Life'])['Satisfaction'].agg(['mean','std'])
print(int_stats)


## Calculate Summary Statistics for the Main Effects ##

import seaborn as sns
import matplotlib.pyplot as plt

## GPS Accuracy Effect ##

gps_effect = shoe.groupby('sole_material')['comfort'].agg(['mean','std']).reset_index()

print(gps_effect)

## Insole Thickness Effect ##

insole_effect = shoe.groupby('insole_thickness')['comfort'].agg(['mean','std']).reset_index()

print(insole_effect)

## Breathability Effect ##

breath_effect = shoe.groupby('breathability')['comfort'].agg(['mean','std']).reset_index()

print(breath_effect)

## Plot Boxplots for Each Factor using seaborn ##

## Sole Material Boxplot ##

sns.boxplot(x='sole_material', y='comfort', data=shoe)
plt.title('Comfort by Sole Material')
plt.show()

## Insole Thickness Boxplot ##

sns.boxplot(x='insole_thickness', y='comfort', data=shoe)
plt.title('Comfort by Insole Thickness')
plt.show()

## Breathability Boxplot ##

sns.boxplot(x='breathability', y='comfort', data=shoe)
plt.title('Comfort by Breathability')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Run_ID        12 non-null     int64
#  1   Replicate     12 non-null     int64
#  2   GPS_Accuracy  12 non-null     object
#  3   Battery_Life  12 non-null     object
#  4   Display       12 non-null     object
#  5   Satisfaction  12 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 708.0+ bytes
# None
#                   mean       std
# GPS_Accuracy
# High          7.140000  2.346691
# Standard      4.606667  1.284098
#                   mean       std
# Battery_Life
# 12 Hours      6.368333  3.189303
# 6 Hours       5.378333  0.496806
#              mean       std
# Display
# Large    7.505000  1.957445
# Small    4.241667  0.886192
#                                mean       std
# GPS_Accuracy Battery_Life
# High         12 Hours      9.266667  0.353883
# ...

# %%
# Install pingouin if not already installed
# !pip install pingouin

import pingouin as pg

# %%
# Perform ANOVA using pingouin
# Note: pingouin expects raw column names for 'between' argument, not C() wrappers
band_anova_pg = pg.anova(dv='Satisfaction',
                         between=['GPS_Accuracy', 'Battery_Life', 'Display'],
                         data=band,
                         ss_type=3)

print("Pingouin ANOVA results:")
print(band_anova_pg)

# %% [markdown]
# 8.  Fit the appropriate ANOVA model to the data. Assess the normality assumption using both a testing method and a visual method. Do we have evidence to support the assumption of normality? Why or why not?
#
# **A factorial ANOVA model was fit to the data. The normality assumption was assessed using both a Q-Q plot and the Shapiro-Wilk test. The Q-Q plot shows that the residuals fall approximately along the reference line, suggesting that the residuals are reasonably normally distributed. Some do deviate but there are no extreme outliers. The Shapiro-Wilk test resulted in a p-value of 0.0916. Since this p-value is greater than 0.05, we fail to reject the null hypothesis that the residuals are normally distributed.**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.diagnostic import het_breuschpagan
import scipy.stats as stats

model = ols('Satisfaction ~ GPS_Accuracy + Battery_Life + Display', data=band).fit()

print(model.summary())

residuals = model.resid

sm.qqplot(residuals, line='s')
plt.title("QQ Plot of Model Residuals")
plt.style.use('classic')
plt.show()

sw = stats.shapiro(residuals)
sw_statistic = sw[0]
sw_p_value = sw[1]

print(f"S-W Statistic: {sw_statistic}")
print(f"S-W p-value: {sw_p_value}")
if sw_p_value < 0.05:
    print("Reject the null hypothesis: Residuals are not normally distributed.")
else:
    print("Fail to reject the null hypothesis: Residuals are normally distributed.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Satisfaction   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     162.0
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           1.68e-07
# Time:                        23:47:17   Log-Likelihood:                -1.4254
# No. Observations:                  12   AIC:                             10.85
# Df Residuals:                       8   BIC:                             12.79
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    9.2667      0.193     48.094      0.000       8.822       9.711
# ...

# %% [markdown]
# 9.  Assess the constant variance assumption using both a testing method and a visual method. Do we have evidence to support the assumption of constant variance? Why or why not?
#
# **Constant variance was assessed using a plot of standardized residuals versus fitted values and the Breusch-Pagan test. The residual plot shows that the points are randomly scattered around zero with no clear pattern or funnel shape, suggesting that the variance is approximately constant. The Breusch-Pagan test resulted in a p-value of 0.8431. Since this p-value is greater than 0.05, we fail to reject the null hypothesis of constant variance. Therefore, there is no evidence to suggest that the variance is not constant, and the assumption of constant variance appears to be satisfied.**

# %%
standardized_residuals = model.get_influence().resid_studentized_internal
fitted_values = model.fittedvalues

plt.figure(figsize=(8, 6))
sns.scatterplot(x=fitted_values, y=standardized_residuals)
plt.axhline(y=0, linestyle='dashed', color='red')
plt.axhline(y=3, color='blue')
plt.axhline(y=-3, color='blue')
plt.xlabel("Predicted y's")
plt.ylabel("Standardized Residuals")
plt.title("Standardized Residuals vs. Fitted Values")
plt.style.use('classic')
plt.show()

bp_test = het_breuschpagan(model.resid, model.model.exog)

f_statistic = bp_test[2]
f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")
if f_p_value < 0.05:
    print("Reject the null hypothesis: Residuals are not homoscedastic.")
else:
    print("Fail to reject the null hypothesis: Residuals are homoscedastic.")
# Out:
# F-statistic: 0.2732704988386917
# F p-value: 0.8431259020641402
# Fail to reject the null hypothesis: Residuals are homoscedastic.

# %% [markdown]
# 10. Report the F-statistics and their associated p-values from the factorial ANOVA model. What conclusions can we draw about our main effects?
#
#
# **For GPS accuracy, the F-statistic is 172.87 and the p-value is less than 0.05, indicating that it is statistically significant.For battery life, the F-statistic is 26.40 and the p-value is less than 0.05, indicating that it is statistically significant.For display size, the F-statistic is 286.85 and the p-value is less than 0.05, indicating that it is statistically significant.
# These results suggest that all three factors—GPS accuracy, battery life, and display size—have a significant effect on user satisfaction.**
#
# **Again, the main effects are aliased with two-way interactions. Therefore, the results should be interpreted with caution.**

# %%
band_tab = sm.stats.anova_lm(model, typ=3)

band_tab["Significance"] = np.where(band_tab['PR(>F)'] < 0.05,
                                    'Significant',
                                    'Not Significant')
print(band_tab.loc[['GPS_Accuracy',
                    'Battery_Life',
                    'Display']])
# Out:
#                  sum_sq   df           F        PR(>F) Significance
# GPS_Accuracy  19.253333  1.0  172.869435  1.065588e-06  Significant
# Battery_Life   2.940300  1.0   26.400000  8.872097e-04  Significant
# Display       31.948033  1.0  286.851029  1.498222e-07  Significant

# %% [markdown]
# 11. Calculate and interpret the values for the main effects. Which effects seem more important? Why?
#
# **The main effects were calculated as the difference between the mean satisfaction at the high and low levels of each factor.**
#
# **For GPS accuracy, the main effect is 7.14 - 4.61 = 2.53**
#
# **For battery life, the main effect is 6.37-5.38 = 0.99**
#
# **For display size, the main effect is 7.51 - 4.24 = 3.27**
#
# **Display size has the largest effect, followed by GPS accuracy, and then battery life. This tells me that display size is the most important factor because it produces the greatest change in user satisfaction.**

# %% [markdown]
# 12. Calculate and interpret the partial $\eta^2$ values for each of the main effects. Which effects are most important? Why?
#
# **Partial $\eta^2$
#  values were calculated to assess the relative importance of each main effect in explaining variability in satisfaction.**
#
# **For GPS accuracy, the partial $\eta^2$
#  value is 0.956.**
#
# **For battery life, the partial $\eta^2$
#  value is 0.767.**
#
# **For display size, the partial $\eta^2$
#  value is 0.973.**
#
# **These results indicate that all three main effects explain a large proportion of the variability in satisfaction. Among them, display size has the largest partial $\eta^2$
#  value, followed by GPS accuracy, while battery life has the smallest value.**
#
# **So, display size seems to be the most important factor, because it has the greatest $\eta^2$.**

# %%
## Calculate Partial Eta Squared ##
# !pip install pingouin

import pingouin as pg


band_anova_pg = pg.anova(dv='Satisfaction',
                         between=['GPS_Accuracy', 'Battery_Life', 'Display'],
                         data=band,
                         ss_type=3)

print("Pingouin ANOVA results:")
print(band_anova_pg)
print(band_anova_pg.loc[band_anova_pg['Source'].isin(['GPS_Accuracy', 'Battery_Life', 'Display'])])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 5.4 MB/s eta 0:00:00
# ...
# Pingouin ANOVA results:
#                                   Source          SS   DF          MS  \
# 0                           GPS_Accuracy   19.253333  1.0   19.253333
# 1                           Battery_Life    2.940300  1.0    2.940300
# 2                                Display   31.948033  1.0   31.948033
# 3            GPS_Accuracy * Battery_Life   31.948033  1.0   31.948033
# 4                 GPS_Accuracy * Display    2.940300  1.0    2.940300
# 5                 Battery_Life * Display   19.253333  1.0   19.253333
# 6  GPS_Accuracy * Battery_Life * Display  413.952533  1.0  413.952533
# 7                               Residual    0.891000  8.0    0.111375
#
#              F         p_unc       np2
# 0   172.869435  1.065588e-06  0.955769
# 1    26.400000  8.872097e-04  0.767442
# 2   286.851029  1.498222e-07  0.972868
# 3   286.851029  1.498222e-07  0.972868
# ...

# %% [markdown]
# 13. Summarize your conclusions. Which combination of factors would you recommend to the fitness band manufacturer? Why?
#
# **Based on all outputs the three factors of GPS accuracy, battery life, and display size have a significant impact on user satisfaction. From the ANOVA results, GPS accuracy (F = 172.87, p < 0.05), battery life (F = 26.40, p < 0.05), and display size (F = 286.85, p < 0.05) are all statistically significant.**
#
# **The main effects tell me that display size has the largest impact (3.27), followed by GPS accuracy (2.53), and then battery life (0.99). This is supported by the partial eta squared values as well, where display size (0.97) explains the most variation in satisfaction, followed by GPS accuracy (0.96) and battery life (0.77).**
#
# **From the interaction results, the highest satisfaction rating (9.27) occurs when GPS accuracy is high and battery life is 12 hours, while the lowest (3.47) occurs when GPS accuracy is standard and battery life is 12 hours.**
#
# **Based on these results, I would recommend using high GPS accuracy with a  12-hour battery life, and the large display, this combination produces the highest satisfaction and is supported by both the main effects and effect size results.**
